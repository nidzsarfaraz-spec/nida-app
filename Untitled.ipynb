# %%
import pandas as pd
import plotly.express as px

# %%
df=pd.read_csv("new file.csv")
pdata=df[df["Player"]=="DG Bradman "]

# %%
pdata
# Out:
#         Player  Duration  Matches  innings  NO  Runs  High_score    Ave  \
# 0  DG Bradman         20       52       80  10  6996         334  99.94
#
#    Balls_faced  Strike_rate  100  50  0   4s  6s Country  start_year  end_year
# 0         9800         58.6   29  13  7  626   6     AUS        1928      1948

# %%
df2=pdata[["100","50","4s","6s","innings","Ave","High_score","Strike_rate"]]

# %%
df2
# Out:
#    100  50   4s  6s  innings    Ave  High_score  Strike_rate
# 0   29  13  626   6       80  99.94         334         58.6

# %%
df3=df2.T.reset_index()

# %%
fig=px.bar(df3,x="index",y=0)

# %%
fig
